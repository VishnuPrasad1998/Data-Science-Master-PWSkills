# %% [markdown]
# Q1. Explain GET and POST methods.

# %% [markdown]
# Ans)
# GET method is mainly used at the client (Browser) side to send a request to a specified server to get certain data or resources
#
# POST method is used at the client (Browser) side to send data to a Specified server in order to create or rewrite a particular resource/data. This data sent to the server is stored in the request body of the HTTP request.

# %% [markdown]
# Q2. Why is request used in Flask?

# %% [markdown]
# The Request, in Flask, is an object that contains all the data sent from the Client to Server. This data can be recovered using the GET/POST Methods

# %% [markdown]
# Q3. Why is redirect() used in Flask?

# %% [markdown]
# Flask redirect is defined as a function or utility in Flask which allows developers to redirect users to a specified URL and assign a specified status code.
# eg.
#
# return redirect(url_for('LoginPage'))

# %% [markdown]
# Q4. What are templates in Flask? Why is the render_template() function used?

# %% [markdown]
# Templates are files that contain static data as well as placeholders for dynamic data. A template is rendered with specific data to produce a final document.
#
# render_template() is used to generate output from a template file based on the Jinja2 engine that is found in the application's templates folder.
#
# eg.
#
# return render_template('folder-name/new.html')

# %% [markdown]
# Q5. Create a simple API. Use Postman to test it. Attach the screenshot of the output in the Jupyter Notebook.

# %% [markdown]
# ![image.png](attachment:63cd4f2c-7b40-49a5-906c-8f9bc10e7acc.png)

# %% [markdown]
# ![image.png](attachment:5ebdb213-5591-4f42-8c7b-ef45aceda643.png)
